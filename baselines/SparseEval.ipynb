# %%
from Sparse_Baselines import OWC, TFIDF, BM25
data_path = "../data/500QA.json"

# %%
OWC_baseline = OWC(data_path)

OWC_baseline.clean_data()
OWC_baseline.get_results()
# Out:
# Total correct answers: 88 out of 500
# {'Specific': 39, 'Subjective': 30, 'Indirect': 42, 'Compound': 18, 'Negated': 19, 'Analogical': 7, 'Temporal': 5}

# %%
TFIDF_baseline = TFIDF(data_path)

cleaned_descriptions = TFIDF_baseline.clean_data()
TFIDF_baseline.calc_df(cleaned_descriptions)
TFIDF_baseline.get_results()
# Out:
# Total correct answers: 108 out of 500
# {'Specific': 46, 'Subjective': 42, 'Indirect': 53, 'Compound': 23, 'Negated': 15, 'Analogical': 12, 'Temporal': 7}
# (108, 500)

# %%
BM25_baseline = BM25(data_path)

cleaned_descriptions = BM25_baseline.clean_data()
BM25_baseline.get_results()
# Out:
# Total correct answers: 97 out of 500
# {'Specific': 151, 'Subjective': 196, 'Indirect': 268, 'Compound': 101, 'Negated': 109, 'Analogical': 30, 'Temporal': 32}
# (97, 500)
