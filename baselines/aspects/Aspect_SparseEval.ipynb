# %%
import sys
sys.path.append('..')

# %%
from Aspect_Sparse_Baselines import OWC, TFIDF, BM25
import numpy as np
import json
from helper import *

# %%
config = load_config()
with open(config['data_path']) as f:
  all_data = json.load(f)

with open(config['folds_path'], 'r', encoding='utf-8') as f:
  folds = json.load(f)

train_inds = folds[0][0]
test_inds = folds[0][2]

test_data = [all_data[i] for i in test_inds]

# %%
def custom_gmean(lst):
  gmean = np.prod(lst)**(1/len(lst))
  return gmean

agg_fcn = min

# %%
OWC_baseline = OWC(test_data)
score_fcn = OWC_baseline.owc_score

OWC_baseline.clean_data()
OWC_baseline.get_results(score_fcn, agg_fcn)
# Out:
# Total correct answers: 10 out of 400
# {'Specific': 5, 'Subjective': 1, 'Indirect': 3, 'Compound': 4, 'Negated': 0, 'Analogical': 0, 'Temporal': 0}
# (10, 400)

# %%
TFIDF_baseline = TFIDF(test_data)
score_fcn = TFIDF_baseline.tfidf_score

cleaned_descriptions = TFIDF_baseline.clean_data()
TFIDF_baseline.calc_df(cleaned_descriptions)
TFIDF_baseline.get_results(score_fcn, agg_fcn)
# Out:
# Total correct answers: 22 out of 400
# {'Specific': 15, 'Subjective': 3, 'Indirect': 10, 'Compound': 6, 'Negated': 3, 'Analogical': 3, 'Temporal': 1}
# (22, 400)

# %%
BM25_baseline = BM25(test_data)
score_fcn = BM25_baseline.bm25_score

cleaned_descriptions = BM25_baseline.clean_data()
BM25_baseline.fit(cleaned_descriptions)
BM25_baseline.get_results(score_fcn, agg_fcn)
# Out:
# Total correct answers: 16 out of 400
# {'Specific': 11, 'Subjective': 5, 'Indirect': 5, 'Compound': 2, 'Negated': 1, 'Analogical': 2, 'Temporal': 0}
# (16, 400)
