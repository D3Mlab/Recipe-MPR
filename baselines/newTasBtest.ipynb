# %% [markdown]
# <a href="https://colab.research.google.com/github/ssanner/lge-foodkg/blob/main/baselines/newTasBtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.0-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 5.1 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 10.5 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 33.1 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 55.9 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.8.1 pyyaml-6.0 tokenizers-0.12.1 transformers-4.21.0

# %%
from transformers import AutoTokenizer, AutoModel
import numpy as np
import torch
import json

# %%
#path = "../../data/data.json" # will be changed to suit data path later
#dataset = json.load(path)

with open("h.json", 'r', encoding='utf-8') as f:
 data = json.load(f)
#path =  # will be changed to suit data path later
dataset = data

# %% [markdown]
# 1. Define a **NeuralEmbedder** class to abstract away the embedding process for the retriever

# %%
class NeuralEmbedder():
  def __init__(self, model_name, tokenizer_name):
    self.tokenizer = AutoTokenizer.from_pretrained(model_name) 
    self.bert_model = AutoModel.from_pretrained(tokenizer_name)
  def embed(self,text):
    return self.bert_model(**self.tokenizer(text,return_tensors="pt"))[0][:,0,:].squeeze(0).numpy()

# %% [markdown]
# 2. Define **the search engine** class. We embedded the documents once and saved the representations in a numpy matrix so we would not have to compute them repeatedly.

# %%
class NeuralSearchEngine():

  def __init__(self, embedder):
    self.embedder = embedder

  def index(self, documents):
    self.documents = documents
    encoded_docs = []
    for d in documents:
      with torch.no_grad():
        d_encoded = self.embedder.embed(d)
      encoded_docs.append(d_encoded.reshape(-1,768))
    self.index = np.concatenate(encoded_docs,axis=0)
  
  def search(self, query):
    with torch.no_grad():
      q_encoded = self.embedder.embed(query).reshape(-1,768)
    scores = q_encoded.dot(self.index.T)[0]

    args = np.argsort(scores)[::-1]

    print("\nThe query:", query,"\nTop three:")

    predicted = ""
    for i in range(3):
      print((i+1),'-','Score:',scores[args[i]],'doc:',self.documents[args[i]])
      if i == 0:
        predicted = self.documents[args[i]]
       
    return predicted

# %% [markdown]
# **Main code**

# %%
def tasb_score(dataset):
  # number of correct predictions
  correct = 0
  # h@1 evaluation metric
  total_hit_at_1 = 0
  # number of queries
  count = 0

  # create an embedder object the tokenizer and model 
  embedder = NeuralEmbedder("sebastian-hofstaetter/distilbert-dot-tas_b-b256-msmarco","sebastian-hofstaetter/distilbert-dot-tas_b-b256-msmarco")

  # loop through each query
  for query in dataset:
    count +=1
    print(count)

    docs = []
    for description in query["options"].values():
      docs.append(description)

    # create a search engine object for this query 
    engine = NeuralSearchEngine(embedder)
    # index the options into the search engine
    engine.index(docs)

    # check if model predicted the correct answer
    if engine.search(query["query"]) == list(query["correct_answer"].values())[0]:
      print(True, ": The correct description has the highest score.","\n")
      correct += 1
      total_hit_at_1 += 1
    else:
      print(False, ": The correct description is:", list(query["correct_answer"].values())[0],"\n")
      
  print("Total correct =", correct)
  print("average h@1",total_hit_at_1/count)

tasb_score(dataset)
# Out:
# 1
#
# The query: I want to make a warm dish containing oysters
# Top three:
# 1 - Score: 101.60317 doc: Simple creamy oyster soup
# 2 - Score: 97.31483 doc: Seasoned salted crackers shaped like oysters
# 3 - Score: 91.15459 doc: Warm vegetable soup containing tomatoes, peas, corn, carrots, and potatoes
# True : The correct description has the highest score.
#
# 2
#
# The query: Can I have a recipe for fish that's roasted?
# Top three:
# 1 - Score: 94.64951 doc: Salmon roasted with olive oil, chives, and tarragon leaves
# 2 - Score: 92.52005 doc: Pecan halves roasted with butter and salt
# 3 - Score: 92.15469 doc: Roasted cauliflower with olive oil and seasonings
# True : The correct description has the highest score.
#
# 3
#
# The query: What are recipes for fish, but not baked in the oven?
# Top three:
# 1 - Score: 105.76575 doc: Fish fillets baked with breaded mixture
# 2 - Score: 99.0171 doc: Breaded fish fillets baked with parmesan cheese
# 3 - Score: 96.07117 doc: Baked halibut fish fillets with Worcestershire sauce
# False : The correct description is: Salmon fillets grilled in a pan with herbs and spices
#
# 4
#
# The query:  I would like a shrimp recipe and I'm trying to eat a balanced diet
# Top three:
# 1 - Score: 92.79398 doc: Shrimp roasted with vegetables in a zesty Italian dressing
# 2 - Score: 90.752785 doc: Shrimp balls made with pork fat deep fried in oil
# 3 - Score: 90.60045 doc: Breaded shrimp with whole milk and creole seasoning deep fried in hot oil
# True : The correct description has the highest score.
#
# 5
#
# The query: Can I have a shrimp pasta recipe for someone with low spice tolerance?
# Top three:
# 1 - Score: 95.29578 doc: Shrimp and vegetables with spaghetti noodles
# 2 - Score: 93.759575 doc: Spaghetti noodles and shrimp containing red pepper flakes
# 3 - Score: 91.549324 doc: Sweet and spicy shrimp skewers containing fresh jalapenos and chili powder
# True : The correct description has the highest score.
#
# 6
#
# The query: I want to make a paella but I'm short on time
# Top three:
# 1 - Score: 97.58455 doc: Paella made with Spanish rice mix, vegetables, and chicken sausage in a slow-cooker
# 2 - Score: 92.96452 doc: Brown rice paella containing mussels and Spanish chorizo that cooks fast
# 3 - Score: 86.18105 doc: Quick guacamole made with avocados, salsa, and lime juice
# False : The correct description is: Brown rice paella containing mussels and Spanish chorizo that cooks fast
#
# 7
#
# The query: What's a lobster recipe without too many ingredients?
# Top three:
# 1 - Score: 101.76852 doc: Lobster recipe made with lots of seasoning, fresh herbs, puffy pastry, truffle oil, egg, essence, difference sauces, and a variety of vegetables
# 2 - Score: 99.09076 doc: Lobster boiled with butter
# 3 - Score: 91.74301 doc: Cheddar biscuits copying the ones at Red Lobster restaurant
# False : The correct description is: Lobster boiled with butter
#
# 8
#
# The query: Can I have a recipe for clam chowder that isn't too fat?
# Top three:
# 1 - Score: 98.84868 doc: Clam chowder made with heavy whipping cream
# 2 - Score: 98.4793 doc: Clam chowder made with half-and-half cream
# 3 - Score: 97.64941 doc: Lighter clam chowder with bacon and vegetables, made with milk instead of cream
# False : The correct description is: Lighter clam chowder with bacon and vegetables, made with milk instead of cream
#
# 9
#
# The query: I would like a beef recipe but not stew
# Top three:
# 1 - Score: 109.90562 doc: Beef stew with a variety of vegetables
# 2 - Score: 103.63528 doc: Beef stew made with ale and Worcestershire sauce
# 3 - Score: 89.06775 doc: Stir-fried beef sirloin steak with peppers and rice
# False : The correct description is: Stir-fried beef sirloin steak with peppers and rice
#
# 10
#
# The query: May I have a chicken recipe that contains bacon?
# Top three:
# 1 - Score: 101.560455 doc: Chicken breasts stuffed with bacon and mozzarella
# 2 - Score: 93.64664 doc: Bacon with Little Smokies sausages and brown sugar
# 3 - Score: 93.071686 doc: Recipe for bacon wrapped duck breasts with Italian salad dressing
# True : The correct description has the highest score.
#
# 11
#
# The query: I want chicken that has a kick to it
# Top three:
# 1 - Score: 93.1105 doc: Hard-cooked egg with a sriracha kick
# 2 - Score: 91.06112 doc: Shrimp With a Kick - made with garlic, olive oil, and fresh cilantro
# 3 - Score: 89.803825 doc: Easy chicken legs made with Italian salad dressing
# False : The correct description is: Chicken wings made with hot chili sauce, butter, and Worcestershire sauce
#
# 12
#
# The query: I like eating pulled meats, but not beef or chicken
# Top three:
# 1 - Score: 92.70173 doc: Sandwiches made with shredded barbecued chicken thighs
# 2 - Score: 91.38145 doc: Shredded barbecued beef with Worcestershire sauce
# 3 - Score: 88.587265 doc: Shredded barbecued pork shoulder
# False : The correct description is: Shredded barbecued pork shoulder
#
# 13
#
# The query: Ways to cook lamb with fragrant seasoning
# Top three:
# 1 - Score: 99.33657 doc: Racks of lamb flavoured with fried rosemary
# 2 - Score: 96.070625 doc: Lamb shoulder seasoned with onion, soy sauce, and oyster sauce
# 3 - Score: 94.88121 doc: Chicken breasts in a rosemary seasoning
# True : The correct description has the highest score.
#
# 14
#
# The query: I want a meat dish suitable for date night
# Top three:
# 1 - Score: 91.40185 doc: No-meat meat pie containing onions and mushrooms
# 2 - Score: 88.38277 doc: Garlic butter strip steaks cooked with onions
# 3 - Score: 88.05522 doc: Meat sauce containing tomato sauce, ground turkey, onion, dried basil, and red wine
# False : The correct description is: Garlic butter strip steaks cooked with onions
#
# 15
#
# The query: I want some crispy chicken like what I could get at KFC
# Top three:
# 1 - Score: 98.20486 doc: Crispy chicken tacos with avocados and red onions
# 2 - Score: 95.73635 doc: KFC style cabbage, carrot, and onion coleslaw
# 3 - Score: 91.96863 doc: Fried chicken wings made with buttermilk and vegetable shortening
# False : The correct description is: Fried chicken wings made with buttermilk and vegetable shortening
#
# 16
#
# The query: I want a dish with meat and I don't like vegetables
# Top three:
# 1 - Score: 96.91264 doc: No-Meat Meat Pie - onions, mushrooms, and cereals in a pie crust
# 2 - Score: 92.556526 doc: Pie filled with bulk sausage, potatoes, onions, and carrots
# 3 - Score: 90.29769 doc: Meatballs made with ground beef and ground pork
# False : The correct description is: Meatballs made with ground beef and ground pork
#
# 17
#
# The query: Can I have a recipe for barbecue meat, but not seafood?
# Top three:
# 1 - Score: 98.720695 doc: Beef short ribs cooked with barbecue sauce
# 2 - Score: 93.37537 doc: Barbecued salmon steaks with dry sherry
# 3 - Score: 91.01795 doc: Barbecue jumbo shrimp with crushed red pepper flakes
# True : The correct description has the highest score.
#
# 18
#
# The query: What is a sausage recipe for someone new to cooking?
# Top three:
# 1 - Score: 94.57445 doc: Mixed sausages braised in sauerkraut, hard cider, apples and onions along with bacon, green cabbage, and pumpernickel bread
# 2 - Score: 90.164185 doc: Breakfast sausages and cream cheese wrapped in Crescent rolls
# 3 - Score: 89.38763 doc: Meat loaf made with pork, onion, carrot, egg, meal, and breadcrumbs
# False : The correct description is: Breakfast sausages and cream cheese wrapped in Crescent rolls
#
# 19
#
# The query: I would like meat lasagna but I'm watching my weight
# Top three:
# 1 - Score: 96.481186 doc: Forgot the Meat Lasagna with onions, mushroom and spinach
# 2 - Score: 94.755424 doc: Beef lasagna with whole wheat noodles, low-fat cottage cheese, and part-skim mozzarella cheese
# 3 - Score: 94.38336 doc: Vegetarian lasagna with mushrooms, mixed vegetables, textured vegetable protein, and meat replacement
# False : The correct description is: Beef lasagna with whole wheat noodles, low-fat cottage cheese, and part-skim mozzarella cheese
#
# 20
#
# The query: I want to make a sauce that goes with my ham
# Top three:
# 1 - Score: 100.5823 doc: Mashed potatoes with ham
# 2 - Score: 95.91701 doc: Brown sugar and mustard glaze for ham
# 3 - Score: 94.1206 doc: Biscuits with ham, mustard, and horseradish
# False : The correct description is: Brown sugar and mustard glaze for ham
#
# 21
#
# The query: Can I have a meatball recipe that doesn't take too long?
# Top three:
# 1 - Score: 96.36707 doc: Beef meatballs cooked in canned soup, ready in 25 minutes
# 2 - Score: 94.43867 doc: Meatballs made with a ground meat substitute
# 3 - Score: 93.52777 doc: Quick and easy cheese ball recipe requiring no cooking
# True : The correct description has the highest score.
#
# 22
#
# The query: I have leftover ground pork and I want to make Asian food
# Top three:
# 1 - Score: 97.28387 doc: Italian sausage made with ground pork and various herbs and spices
# 2 - Score: 95.89009 doc: Chinese-style steamed pork meatloaf
# 3 - Score: 94.2642 doc: Balkan burger containing three types of ground meat including ground beef, ground veal, and ground pork
# False : The correct description is: Chinese-style steamed pork meatloaf
#
# 23
#
# The query: What beef recipe can I make if I like spicy food?
# Top three:
# 1 - Score: 93.46154 doc: Beef steaks flavoured with fresh mango
# 2 - Score: 92.224434 doc: Spicy scallops cooked with sambal oelek chili paste
# 3 - Score: 92.09493 doc: Spicy shrimp seasoned with Tabasco sauce and chili powder
# False : The correct description is: Beef chili containing jalapeno pepper, chili powder, cayenne pepper, and ground chipotle chile pepper
#
# 24
#
# The query: Bacon breakfast recipe for beginners
# Top three:
# 1 - Score: 97.6173 doc: Cheesy bacon dip for snacking
# 2 - Score: 97.06662 doc: Bacon cinnamon rolls using premade biscuits
# 3 - Score: 95.2708 doc: Sausage, egg, and cheese breakfast taco recipe
# False : The correct description is: Bacon cinnamon rolls using premade biscuits
#
# 25
#
# The query: Can I have a recipe containing ground pork and beef?
# Top three:
# 1 - Score: 104.344894 doc: Beef croquettes recipe containing ground beef
# 2 - Score: 103.62001 doc: Liverwurst sausage recipe made with ground pork
# 3 - Score: 102.38653 doc: Meat stuffing made with ground beef, pork sausage, ground pork, onion, turkey gizzard, and potatoes
# False : The correct description is: Meat stuffing made with ground beef, pork sausage, ground pork, onion, turkey gizzard, and potatoes
#
# 26
#
# The query: I miss my mom's noodle soup, is there a recipe for that?
# Top three:
# 1 - Score: 90.86574 doc: Mom's stroganoff - contains ground beef, onions, and mushrooms
# 2 - Score: 90.315834 doc: Creamy garlic soup with leeks, potatoes, and carrots
# 3 - Score: 89.15813 doc: Noodles made with zucchini and topped with parmesan cheese
# False : The correct description is: Wide egg noodles, chicken legs, onions, carrots, and celery in chicken broth
#
# 27
#
# The query: What can I do with a leftover loaf of bread?
# Top three:
# 1 - Score: 96.69479 doc: Baked banana bread using mashed bananas
# 2 - Score: 94.26804 doc: Breadcrumbs made using premade bread (not from scratch)
# 3 - Score: 93.91694 doc: Easy buttermilk bread recipe for bread machines
# False : The correct description is: Breadcrumbs made using premade bread (not from scratch)
#
# 28
#
# The query: What's a filling rice dish I can make?
# Top three:
# 1 - Score: 96.89532 doc: Chicken legs and rice recipe enough for two people
# 2 - Score: 90.59115 doc: Spicy snack with puffed rice cereal, wasabi peas, pumpkin seeds, and roasted soybeans
# 3 - Score: 89.68013 doc: Strawberry filling made with strawberries, rum, sugar, and orange zest
# True : The correct description has the highest score.
#
# 29
#
# The query: Can I have noodles but not Italian?
# Top three:
# 1 - Score: 99.137245 doc: Italian-style wide egg noodles with beef, beans, tomatoes, and cheese
# 2 - Score: 94.16686 doc: Spaghetti noodle recipe with bell peppers, meat, and tomato sauce
# 3 - Score: 90.441284 doc: Szechuan-style spicy lo mein noodles with bell peppers
# False : The correct description is: Szechuan-style spicy lo mein noodles with bell peppers
#
# 30
#
# The query: I want to cook noodles in a wok
# Top three:
# 1 - Score: 95.274345 doc: Noodles stir-fried with cabbage, sliced mushrooms, carrots, green beans, ham
# 2 - Score: 93.42777 doc: Egg noodles in chicken soup with onions, cilantro, and ground turkey
# 3 - Score: 91.20115 doc: Potato gnocchi stir-fried with cabbage and onions
# True : The correct description has the highest score.
#
# 31
#
# The query: How do I make garlic bread that's cheesy?
# Top three:
# 1 - Score: 104.30193 doc: Cheesy garlic potato bake made with cream cheese
# 2 - Score: 102.7291 doc: Garlic herb bread made with parsley
# 3 - Score: 101.70593 doc: Garlic bread with cheddar, green onions, and mayonnaise
# False : The correct description is: Garlic bread with cheddar, green onions, and mayonnaise
#
# 32
#
# The query: What are some recipes for this cold day that contain canned beans?
# Top three:
# 1 - Score: 101.22647 doc: Cold salad with a variety of canned beans, lentils, chickpeas, onions, and bacon
# 2 - Score: 99.243576 doc: Taco soup made with canned pinto beans and canned kidney beans
# 3 - Score: 88.06773 doc: Soup made with whole chicken, rice, onion, avgolemono sauce, salt, and pepper
# False : The correct description is: Taco soup made with canned pinto beans and canned kidney beans
#
# 33
#
# The query: Teach me how to make European-style pastries
# Top three:
# 1 - Score: 95.82198 doc: Swedish butter pastries
# 2 - Score: 93.854866 doc: European-style cheesecake with a graham cracker crust
# 3 - Score: 88.27789 doc: Samosa recipe (Indian style savory stuffed pastry)
# True : The correct description has the highest score.
#
# 34
#
# The query: I'm really craving seafood spaghetti, can I have a recipe for that?
# Top three:
# 1 - Score: 94.6494 doc: Seafood linguini recipe containing shrimp
# 2 - Score: 94.15711 doc: Spaghetti noodles with mussels, anchovy fillets, and capers
# 3 - Score: 93.84191 doc: Spaghetti noodles with beef meatballs
# False : The correct description is: Spaghetti noodles with mussels, anchovy fillets, and capers
#
# 35
#
# The query: Give me some bread recipes that are low in fat
# Top three:
# 1 - Score: 103.732544 doc: Low fat cookies containing apple sauce and whole wheat flour
# 2 - Score: 97.92604 doc: Low fat pancakes containing unsweetened apple sauce, skim milk, whole wheat flour, and sugar substitute
# 3 - Score: 95.32973 doc: Zucchini bread with nonfat yogurt, sugar substitute, and whole wheat flour
# False : The correct description is: Zucchini bread with nonfat yogurt, sugar substitute, and whole wheat flour
#
# 36
#
# The query: What's a pasta recipe that doesn't contain meat?
# Top three:
# 1 - Score: 98.13246 doc: Eggplant bolognese pasta containing ground meat
# 2 - Score: 96.03127 doc: Pasta noodle salad with tuna and a variety of vegetables
# 3 - Score: 93.05798 doc: Farfalle pasta with chicken, red peppers, and olives in pesto sauce
# False : The correct description is: Whole wheat spaghetti with a variety of vegetables: tomatoes, red onion, yellow bell pepper, red bell pepper, zucchini, fresh mushrooms
#
# 37
#
# The query: How to make rice in a pan?
# Top three:
# 1 - Score: 99.094025 doc: Mexican-style rice cooked in a rice cooker
# 2 - Score: 98.51959 doc: Sweet rice pudding cooked in a rice cooker
# 3 - Score: 94.31157 doc: Fried rice containing eggs, onion, frozen peas, and pork chop
# False : The correct description is: Fried rice containing eggs, onion, frozen peas, and pork chop
#
# 38
#
# The query: What's a low-difficulty potato recipe?
# Top three:
# 1 - Score: 93.28254 doc: Easy sweet potatoes with butter, sugar, pecans, and Bourbon
# 2 - Score: 93.18102 doc: Simple potato bake with cheese, ham, sour cream, and onion
# 3 - Score: 91.66775 doc: Not Difficult At All: Oi-sobagi (Stuffed Cucumber Kimchi) recipe
# False : The correct description is: Simple potato bake with cheese, ham, sour cream, and onion
#
# 39
#
# The query: What are some recipes containing corn that aren't too fat?
# Top three:
# 1 - Score: 93.15388 doc: Corn on the cob fried with butter and bacon drippings
# 2 - Score: 93.145386 doc: Corn chowder made with skim milk and low-sodium vegetable broth
# 3 - Score: 91.5406 doc: Low fat apple and butternut squash soup made with light cheddar cheese
# False : The correct description is: Corn chowder made with skim milk and low-sodium vegetable broth
#
# 40
#
# The query: I would like lunch recipes with beans but not spicy
# Top three:
# 1 - Score: 98.21987 doc: Three bean salad with spicy peppers and Italian dressing
# 2 - Score: 97.85672 doc: Beef chili containing spicy chili beans and chili powder
# 3 - Score: 96.51999 doc: Sweet salad made with corn and three types of beans
# False : The correct description is: Sweet salad made with corn and three types of beans
#
# 41
#
# The query: I want to make a dessert with my brown rice
# Top three:
# 1 - Score: 98.17964 doc: Dessert treat made with butter, mini marshmallows, and Rice Krispie cereal
# 2 - Score: 97.91034 doc: Long-grain white rice dish with onions
# 3 - Score: 97.670616 doc: Brown rice and mushrooms cooked with vegetable stock, olive oil, and rice vinegar
# False : The correct description is: Blueberry crisp containing blueberries, brown rice, rice bran, and walnuts
#
# 42
#
# The query: I want to make fries but I don't have potatoes
# Top three:
# 1 - Score: 97.698044 doc: Russet potato fries made with peanut oil and salt
# 2 - Score: 96.80983 doc: Fried potatoes with bacon and onion
# 3 - Score: 95.64184 doc: Simple sweet potato fries seasoned with salt and black pepper
# False : The correct description is: Simple sweet potato fries seasoned with salt and black pepper
#
# 43
#
# The query: Ways to cook asparagus without an oven
# Top three:
# 1 - Score: 101.02592 doc: Baked asparagus casserole dish with Worcestershire sauce
# 2 - Score: 98.76698 doc: Creamy asparagus bake with cheddar cheese
# 3 - Score: 97.00077 doc: Steamed asparagus with olive oil, black pepper, salt, and lemon
# False : The correct description is: Steamed asparagus with olive oil, black pepper, salt, and lemon
#
# 44
#
# The query: What's a broccoli recipe that kids will like?
# Top three:
# 1 - Score: 102.06163 doc: Creamy broccoli dish with mayonnaise and cheddar cheese for kids
# 2 - Score: 96.458664 doc: Broccoli and onions cooked with red wine
# 3 - Score: 94.91024 doc: Carrots, tomatoes, pepper, onions, and spinach vegetable balls for kids
# True : The correct description has the highest score.
#
# 45
#
# The query: Can I have a brussel sprouts recipe with common ingredients?
# Top three:
# 1 - Score: 102.01999 doc: Brussel sprouts made with olive oil, garlic, and parmesan cheese
# 2 - Score: 101.38408 doc: Brussel sprout slaw made with a variety of sauces and seasonings, pecans, and pomegranate seeds
# 3 - Score: 94.128525 doc: Simple quinoa sprouts recipe only requiring distilled water
# True : The correct description has the highest score.
#
# 46
#
# The query: I want a hearty dish that has carrots
# Top three:
# 1 - Score: 98.84865 doc: Hearty cabbage soup also containing potatoes, celery, and onions
# 2 - Score: 97.78976 doc: Carrot soup that contains onions, curry seasoning, cream, and butter
# 3 - Score: 96.97157 doc: Hearty potato soup containing onions, potatoes, celery and turkey bacon
# False : The correct description is: Carrot soup that contains onions, curry seasoning, cream, and butter
#
# 47
#
# The query: I want a salad that has both vegetables and protein
# Top three:
# 1 - Score: 101.23546 doc: Vegetable salad containing onions, tomatoes, capsicum, and cabbage
# 2 - Score: 97.12859 doc: Salad dressing made with a tomato soup base
# 3 - Score: 95.22444 doc: Caesar salad with cooked chicken, lettuce, tomatoes, croutons, and cheese
# False : The correct description is: Caesar salad with cooked chicken, lettuce, tomatoes, croutons, and cheese
#
# 48
#
# The query: I would like a comforting recipe with mushrooms for a cold day
# Top three:
# 1 - Score: 100.69043 doc: Cold mushrooms on spinach with sauces and seasonings
# 2 - Score: 94.15682 doc: Creamy soup with four types of mushrooms, onions, and rice
# 3 - Score: 91.8265 doc: Mushroom and lettuce salad with green onions
# False : The correct description is: Creamy soup with four types of mushrooms, onions, and rice
#
# 49
#
# The query: Can I have buffalo cauliflower like the ones from Boston Pizza?
# Top three:
# 1 - Score: 106.44914 doc: Boston Pizza-style breaded cauliflower bites with buffalo flavouring
# 2 - Score: 96.23989 doc: Boston-Pizza style pizza with chicken, bacon, pineapple, and hot sauce
# 3 - Score: 94.36322 doc: Cauliflower cooked with onions and tomatoes in curry sauce
# True : The correct description has the highest score.
#
# 50
#
# The query: How do I cook a zucchini in the oven?
# Top three:
# 1 - Score: 100.47939 doc: Zucchini baked with onion, poppy seeds, and cheese
# 2 - Score: 98.61251 doc: Zucchini stir-fried with salad oil, water, salt, and sugar
# 3 - Score: 93.11309 doc: Zucchini slaw also containing onions with Italian salad dressing
# True : The correct description has the highest score.
#
# 51
#
# The query: I would like a salad but I don't like kale
# Top three:
# 1 - Score: 98.55844 doc: Vegetable salad containing kale, watercress, ham, tomatoes, scallions, peppers, and capers
# 2 - Score: 95.88945 doc: Lemon-flavoured sweet potato, carrots, zucchini, and kale salad with beans
# 3 - Score: 95.775475 doc: 3-ingredient kale and peach salad with vinaigrette dressing
# False : The correct description is: Salad with a variety of vegetables, kidney beans, and Italian dressing
#
# 52
#
# The query: I want to make vegetable soup but I don't have much time
# Top three:
# 1 - Score: 101.771904 doc: Quick soup with a variety of vegetables and made using vegetable stock
# 2 - Score: 95.11673 doc: Quick beef and vegetable soup with French bread
# 3 - Score: 94.267555 doc: Slow-cooked soup with a variety of vegetables, beans, and a five cheese blend
# True : The correct description has the highest score.
#
# 53
#
# The query: I'd like a cucumber recipe where the cucumbers aren't cooked
# Top three:
# 1 - Score: 98.47163 doc: Cucumbers baked with butter, dill seeds, fresh pepper, and salt
# 2 - Score: 96.66586 doc: Creamy cucumber soup containing curry powder
# 3 - Score: 93.3121 doc: Cucumber and red onion salad containing sour cream
# False : The correct description is: Cucumber and red onion salad containing sour cream
#
# 54
#
# The query: I want a dip with vegetables to go with my tortilla chips for snack
# Top three:
# 1 - Score: 97.85631 doc: Cherry cream cheese dip with cinnamon tortillas
# 2 - Score: 93.45695 doc: Chocolate dip made with chocolate chips and heavy cream
# 3 - Score: 88.54529 doc: Salsa made with pineapple, mangoes, onions, black beans, corn, strawberries, jalapeno, and tomatoes
# False : The correct description is: Salsa made with pineapple, mangoes, onions, black beans, corn, strawberries, jalapeno, and tomatoes
#
# 55
#
# The query: I want a green smoothie to have after my workout
# Top three:
# 1 - Score: 99.84009 doc: Berry post workout smoothie containing fresh raspberries strawberries, blueberries, and banana
# 2 - Score: 91.67127 doc: Garden veggie smoothie containing tomatoes, celery, parsley, and spinach
# 3 - Score: 90.14092 doc: Pineapple smoothie containing buttermilk
# False : The correct description is: Garden veggie smoothie containing tomatoes, celery, parsley, and spinach
#
# 56
#
# The query: What are some spinach or kale-based dishes I can make in the oven?
# Top three:
# 1 - Score: 95.5605 doc: Spinach and kale smoothie also containing banana, chia seeds, peanut butter, and almond milk
# 2 - Score: 95.396835 doc: Sauteed kale with onion, olive oil, and sea salt
# 3 - Score: 95.16566 doc: Baked spinach quiche containing bacon
# False : The correct description is: Baked spinach quiche containing bacon
#
# 57
#
# The query: Can I have a recipe with green peppers and meat?
# Top three:
# 1 - Score: 103.46129 doc: Green peppers, onions, seasonings, and rice
# 2 - Score: 99.106125 doc: "Butter" made from green peppers, butter, salt, cayenne pepper, and garlic
# 3 - Score: 98.96478 doc: Chuck round steaks with green peppers
# False : The correct description is: Chuck round steaks with green peppers
#
# 58
#
# The query: I want vegetables for a breakfast meal
# Top three:
# 1 - Score: 96.83737 doc: Sausage, lunchmeat, and bacon breakfast cups
# 2 - Score: 93.982864 doc: Broccoli, cauliflower, and mushroom vegetable snack with salad dressing
# 3 - Score: 89.480644 doc: Breakfast sausage made from scratch using pork shoulder
# False : The correct description is: Scramble containing mushrooms, onions, corn, tomatoes, and avocados
#
# 59
#
# The query: I would like a tomato recipe that isn't soup
# Top three:
# 1 - Score: 101.01552 doc: Creamy tomato soup containing chili powder
# 2 - Score: 98.24211 doc: Pumpkin seed soup containing tomatoes, onion, habanero peppers, shrimp, and spinach
# 3 - Score: 91.04156 doc: Tomato couscous with green beans, olives, parsley, and pinto beans
# False : The correct description is: Tomato couscous with green beans, olives, parsley, and pinto beans
#
# 60
#
# The query: How do I cook green beans in the oven?
# Top three:
# 1 - Score: 101.17674 doc: Green beans sauteed with bacon and almonds
# 2 - Score: 100.37764 doc: Green beans roasted with fresh ginger
# 3 - Score: 98.352806 doc: Green beans cooked with red pepper, onion, and cashews in Teriyaki sauce
# False : The correct description is: Green beans roasted with fresh ginger
#
# 61
#
# The query: I want a creamy pasta
# Top three:
# 1 - Score: 92.1696 doc: Capellini pasta with breadcrumbs, walnuts, raisins, and other seasoning
# 2 - Score: 91.57431 doc: Creamy corn and other vegetables made with half-and-half cream
# 3 - Score: 91.42896 doc: Creamy hummus made from garbanzo beans
# False : The correct description is: Chicken and vegetable fettuccine made using milk, cream cheese, and parmesan cheese
#
# 62
#
# The query: What's a snack recipe containing cheddar cheese?
# Top three:
# 1 - Score: 104.07056 doc: Cheddar cheese and cracker bites
# 2 - Score: 100.10784 doc: Snack made with pita bread, parmesan cheese, and seasonings
# 3 - Score: 95.89962 doc: Cheddar cheese pasta pie with avocados, tomato sauce, and chipotle chili in adobo
# True : The correct description has the highest score.
#
# 63
#
# The query: How do I make cream puffs that don't have too many calories?
# Top three:
# 1 - Score: 101.59307 doc: Cream puffs made with low-fat margarine
# 2 - Score: 101.31542 doc: Chocolate cream puffs made with heavy cream
# 3 - Score: 97.89484 doc: Almond cream puffs made with heavy whipping cream and whole milk
# True : The correct description has the highest score.
#
# 64
#
# The query: Recipe for a dessert with cream cheese in it
# Top three:
# 1 - Score: 111.115395 doc: Cheesecake made with cream cheese
# 2 - Score: 98.81474 doc: Recipe for dessert crepes containing rum
# 3 - Score: 97.52174 doc: Paneer cheese made with milk, lemons, and water for curry and desserts
# True : The correct description has the highest score.
#
# 65
#
# The query: What's a treat I can make for myself with milk during this heat wave?
# Top three:
# 1 - Score: 97.45604 doc: Treats for dogs that contain milk
# 2 - Score: 89.564255 doc: Peanut ice cream made from scratch using milk
# 3 - Score: 87.819336 doc: Cold drink made with mint, ice cubes, vodka, Midori melon liqueur, lime, and club soda for the summer heat
# False : The correct description is: Peanut ice cream made from scratch using milk
#
# 66
#
# The query: I would like a recipe for salad with yogurt dressing
# Top three:
# 1 - Score: 112.27167 doc: Simple yogurt and lemon dressing recipe that can be used for salads
# 2 - Score: 106.6389 doc: Strawberry and spinach salad with a strawberry yogurt dressing
# 3 - Score: 95.6939 doc: Caesar salad dressing recipe made from scratch using raw cashews
# False : The correct description is: Strawberry and spinach salad with a strawberry yogurt dressing
#
# 67
#
# The query: My favourite dessert is ice cream but I don't like fruity flavours
# Top three:
# 1 - Score: 97.96932 doc: Ice cream made with fresh strawberries
# 2 - Score: 97.918 doc: Super-fruity ice cream smoothie made with pineapple chunks
# 3 - Score: 94.409325 doc: Cookies and cream ice cream made with oreo cookies
# False : The correct description is: Cookies and cream ice cream made with oreo cookies
#
# 68
#
# The query: What can I make if I have butter and milk?
# Top three:
# 1 - Score: 99.85571 doc: Sugar cookies with icing containing butter and milk
# 2 - Score: 83.997696 doc: Fortune cookie recipe from scratch made using egg whites
# 3 - Score: 82.080215 doc: Ground pork dumplings with ginger and scallions
# True : The correct description has the highest score.
#
# 69
#
# The query: I want a cheesy dip for my afternoon snack
# Top three:
# 1 - Score: 91.978264 doc: Dip for chips made from sour cream, deviled ham, and onion soup mix
# 2 - Score: 91.40338 doc: Cheddar cheese and elbow macaroni with onions
# 3 - Score: 91.20988 doc: Crabmeat dip containing red peppers, onion, and cream cheese
# False : The correct description is: Super-fruity ice cream smoothie made with pineapple chunks
#
# 70
#
# The query: What's a noodle dish I can make with a creamy sauce?
# Top three:
# 1 - Score: 96.68694 doc: Spaghetti noodles with marinara sauce made with olive oil, garlic, tomatoes, salt, black pepper, basil, and parsley
# 2 - Score: 95.17909 doc: Pesto sauce for noodles made from basil leaves, parmesan cheese, pine nuts, garlic, and olive oil
# 3 - Score: 95.154594 doc: Creamy lemon sauce made with flour, lemons, black pepper, and heavy whipping cream
# False : The correct description is: Spaghetti with mushrooms, onion, green pepper, chicken breasts, and alfredo sauce
#
# 71
#
# The query: What's a drink I can make containing chocolate?
# Top three:
# 1 - Score: 99.84181 doc: Chocolate cream pie made with heavy cream and three types of chocolate
# 2 - Score: 97.57936 doc: Chocolate and orange-flavoured smoothie
# 3 - Score: 97.57465 doc: Drink made with milk, cream, pineapple chunks, and pineapple jelly
# False : The correct description is: Chocolate and orange-flavoured smoothie
#
# 72
#
# The query: Recipes for mac and cheese with multiple types of cheese
# Top three:
# 1 - Score: 103.12071 doc: Grilled cheese sandwich with four types of cheese
# 2 - Score: 100.86464 doc: Macaroni made with ricotta, parmesan, cheddar, mozzarella, and cream cheese
# 3 - Score: 99.02749 doc: Macaroni cooked with salt, pepper, cheddar cheese, butter, and skim milk
# False : The correct description is: Macaroni made with ricotta, parmesan, cheddar, mozzarella, and cream cheese
#
# 73
#
# The query: I would like a dessert that's creamy
# Top three:
# 1 - Score: 92.48181 doc: Cherry dessert made with bisquick and cherry pie filling
# 2 - Score: 91.187836 doc: Dessert made from rice krispies, fruit roll-ups, and gummy worms
# 3 - Score: 89.367584 doc: Creamy turnip soup containing potatoes, onions, celery, and carrots
# False : The correct description is: Oreo pie made with oreo cookies, butter, milk, and a tub of Cool Whip
#
# 74
#
# The query: How to easily make homemade yogurt?
# Top three:
# 1 - Score: 105.81502 doc: 2-ingredient yogurt from scratch
# 2 - Score: 102.21738 doc: Strawberry frozen yogurt made from plain yogurt
# 3 - Score: 95.412895 doc: Yogurt smoothie made with low-fat yogurt, cool-whip, and strawberries
# True : The correct description has the highest score.
#
# 75
#
# The query: Can I have a simple cheese pizza?
# Top three:
# 1 - Score: 100.45328 doc: Pizza with mozzarella cheese and pepperoni
# 2 - Score: 99.30729 doc: Pizza made with three types of cheese, 2 types of sausage, and pepperoni
# 3 - Score: 96.64248 doc: Bacon, lettuce, and tomato pizza with monterey jack cheese and cream cheese
# False : The correct description is: 3-ingredient pizza with mozzarella topping
#
# 76
#
# The query: I want to make cheesy finger foods for my party
# Top three:
# 1 - Score: 94.97461 doc: Party wrapped angel food cake made with fresh fruits
# 2 - Score: 94.9374 doc: Perfect scallop finger food made with bay scallops, egg roll wraps, oil, lime juice, bacon, mayonnaise, and chili oil
# 3 - Score: 94.43692 doc: Cheesy tuna salad made with three different types of cheese
# False : The correct description is: Baked mozzarella cheese sticks with marinara sauce
#
# 77
#
# The query: How to make berry jam at home?
# Top three:
# 1 - Score: 98.90556 doc: Jam made from blackberries, lemon juice, and sugar
# 2 - Score: 98.03781 doc: Jam made from apples, lemon juice, and sugar
# 3 - Score: 97.95915 doc: Cookies with a jam filling
# True : The correct description has the highest score.
#
# 78
#
# The query: I have a lot of apples, what can I bake with them?
# Top three:
# 1 - Score: 97.84676 doc: No-Bake apple crumble containing walnuts, dates, and raisins
# 2 - Score: 95.41414 doc: Apple pie made with apples, cinnamon, sugar, butter, and premade shell and crust
# 3 - Score: 94.850006 doc: Caramel apple jam made with granny smith and braeburn apples
# False : The correct description is: Apple pie made with apples, cinnamon, sugar, butter, and premade shell and crust
#
# 79
#
# The query: My family wants a recipe for peach cobbler that's healthier
# Top three:
# 1 - Score: 100.617035 doc: Peach cobbler dessert containing whole wheat flour
# 2 - Score: 99.643105 doc: Peach cobbler made with cream cheese, pie filling, sugar, and crescent rolls
# 3 - Score: 97.95645 doc: Cobbler dessert made using three types of berries
# True : The correct description has the highest score.
#
# 80
#
# The query: What can I make with frozen berries that's not a drink?
# Top three:
# 1 - Score: 101.45913 doc: Berry cobbler that uses frozen mixed berries
# 2 - Score: 96.763664 doc: Red wine sangria made with frozen mixed berries, lemon, and oranges
# 3 - Score: 94.64109 doc: Smoothie made from bananas, mixed berry yogurt, frozen mixed berries, and pomegranates
# True : The correct description has the highest score.
#
# 81
#
# The query: I want a tropical fruit drink that reminds me of Hawaii
# Top three:
# 1 - Score: 96.61148 doc: Tropical fruit salad containing mangoes, papayas, pineapple, kiwi fruits, and banana
# 2 - Score: 91.66922 doc: Tropical oatmeal made with coconut extract, bananas, and a sugar substitute
# 3 - Score: 90.23526 doc: Pineapple coconut smoothie that's made with almond milk
# False : The correct description is: Pineapple coconut smoothie that's made with almond milk
#
# 82
#
# The query: I would like either apple or cherry pie recipes
# Top three:
# 1 - Score: 101.0546 doc: Cheesecake containing cherry pie filling
# 2 - Score: 100.858345 doc: Cake made with apples
# 3 - Score: 100.73194 doc: Cherry pie made with dark sweet cherries
# False : The correct description is: Cherry pie made with dark sweet cherries
#
# 83
#
# The query: Could I have a fruit salad containing a variety of fruits?
# Top three:
# 1 - Score: 105.51282 doc: Salad made from 5 fruits: oranges, strawberries, blackberries, grapes, and pears
# 2 - Score: 98.28871 doc: Salad containing spinach, strawberries, walnuts, feta cheese, and vinaigrette
# 3 - Score: 89.25202 doc: Fruit smoothie made with papaya nectar, yogurt, bananas, strawberries, and honey
# True : The correct description has the highest score.
#
# 84
#
# The query: Give me a fruit cake recipe but I'm allergic to pineapple
# Top three:
# 1 - Score: 101.2411 doc: Cake containing crushed pineapple, pecans, and coconut
# 2 - Score: 98.27409 doc: Cake made with candied cherries, candied pineapple, dates, currants, and citron
# 3 - Score: 95.90433 doc: Cake baked with apples and walnuts
# False : The correct description is: Cake baked with apples and walnuts
#
# 85
#
# The query: What are some fruit smoothie recipes that don't contain dairy?
# Top three:
# 1 - Score: 103.58179 doc: Smoothie containing strawberries, bananas, yogurt, and nonfat milk
# 2 - Score: 101.77909 doc: Fruit smoothie made from fruit juice and bananas
# 3 - Score: 99.26467 doc: Strawberry smoothie with oats and flax made using low-fat milk
# False : The correct description is: Fruit smoothie made from fruit juice and bananas
#
# 86
#
# The query: I would like some strawberry breakfast recipes
# Top three:
# 1 - Score: 92.61522 doc: Chicken breasts marinated in a strawberry-lemonade sauce
# 2 - Score: 92.18444 doc: Breakfast quiche with onions, swiss cheese, and bacon
# 3 - Score: 91.82242 doc: Berry dinner salad - mixed greens with dried cranberries, sunflower seeds, avocados
# False : The correct description is: Pops made with strawberries and chia seeds
#
# 87
#
# The query: Can I have a banana bread recipe that contains nuts?
# Top three:
# 1 - Score: 110.264725 doc: Banana bread made with whole wheat flour and contains walnuts
# 2 - Score: 104.56001 doc: Nut-free banana bread containing sour cream
# 3 - Score: 101.09337 doc: Banana pudding made with instant pudding mix
# True : The correct description has the highest score.
#
# 88
#
# The query: Can I have a creamy fruit salad without kiwi?
# Top three:
# 1 - Score: 104.757 doc: Fruit salad with grapes, strawberries, and kiwi fruits
# 2 - Score: 96.89261 doc: Tart made using fresh kiwi fruits
# 3 - Score: 94.98468 doc: Fruit salad with 7 fruits, lime juice, and sugar
# False : The correct description is: Vanilla pudding fruit salad containing cantaloupe, watermelon, nectarines, strawberries, blueberries, and grapes
#
# 89
#
# The query: How do I make a classic French fruit tart?
# Top three:
# 1 - Score: 101.085075 doc: French fruit tart with grapes, kiwi, and strawberries
# 2 - Score: 95.4586 doc: Italian fruit tart with raspberries and mascarpone cheese
# 3 - Score: 95.39023 doc: French macarons containing orange flavouring
# True : The correct description has the highest score.
#
# 90
#
# The query: I would like a pear cake recipe for beginners
# Top three:
# 1 - Score: 105.077774 doc: Easy-to-make cake made with Asian pears
# 2 - Score: 99.48442 doc: Rice flour sponge cake for beginners to make
# 3 - Score: 97.26981 doc: Fresh pear and chocolate tart dessert
# True : The correct description has the highest score.
#
# 91
#
# The query: Recipes for lemon cake like the ones from Starbucks
# Top three:
# 1 - Score: 97.37428 doc: Grandma's apple cake with cinnamon
# 2 - Score: 95.77641 doc: Copy of Starbucks cranberry bliss bar containing dried cranberries, white chocolate, and lemon juice
# 3 - Score: 94.922905 doc: Lemon pie with graham cracker crust
# False : The correct description is: Lemon loaf made with flour, baking powder, salt, shortening, sugar, eggs, lemons, milk
#
# 92
#
# The query: Give me some pineapple recipes that aren't dessert
# Top three:
# 1 - Score: 101.08852 doc: Dessert made with crushed pineapple, shredded coconut, white cake mix, and butter
# 2 - Score: 96.20892 doc: Pineapple cheesecake with ladyfingers and strawberries
# 3 - Score: 93.08207 doc: Homemade pizza with pineapple, ham, and Anjou pear
# False : The correct description is: Homemade pizza with pineapple, ham, and Anjou pear
#
# 93
#
# The query: I would like a lunch dish that's spicy
# Top three:
# 1 - Score: 102.32889 doc: Spicy mustard sauce that goes well with meats
# 2 - Score: 90.53915 doc: Tacos with fish fillets and green chilies
# 3 - Score: 89.702255 doc: Lunch dish for kids containing ham, carrots, yellow cheese, green grapes, M & M's, and grape kool-aid
# False : The correct description is: Tacos with fish fillets and green chilies
#
# 94
#
# The query: I'm craving something sweet and sour, what can I make?
# Top three:
# 1 - Score: 89.700165 doc: Sour bean, wheat, lentil, and swiss chard soup containing lemon juice
# 2 - Score: 86.977135 doc: Black tea sweetened with condensed milk
# 3 - Score: 83.78619 doc: Pork cooked with onions, peppers, pineapple chunks, ketchup, karo syrup, and cider vinegar
# False : The correct description is: Pork cooked with onions, peppers, pineapple chunks, ketchup, karo syrup, and cider vinegar
#
# 95
#
# The query: Show me a recipe for savoury crepes
# Top three:
# 1 - Score: 98.99945 doc: Easy crepes with chicken, garlic, and herb filling
# 2 - Score: 95.33058 doc: Crepes with blueberries, strawberry jam, cherry brandy, and lemon juice
# 3 - Score: 94.50391 doc: Sweet crepes with Cool Whip topping, chocolate, and almonds
# True : The correct description has the highest score.
#
# 96
#
# The query: I want to make something warm with chili peppers
# Top three:
# 1 - Score: 99.61681 doc: Chili made with ground beef, onions, beans, and green chili peppers
# 2 - Score: 93.35158 doc: Fresh pineapple mixed with chili peppers, sugar, and coarse salt
# 3 - Score: 91.3675 doc: Rice, meat, catsup, and breadcrumb stuffing for green peppers
# True : The correct description has the highest score.
#
# 97
#
# The query: I want a snack that's sweet like candy
# Top three:
# 1 - Score: 94.12404 doc: Savoury seasoned snack mix with popcorn, Cheez-Its, Chex, pretzel twists, and smoked almonds
# 2 - Score: 91.296104 doc: Smores dessert bars containing chocolate chips and marshmallow cream
# 3 - Score: 91.16142 doc: Cracker snack with cheese spread, ham, and tomatoes
# False : The correct description is: Smores dessert bars containing chocolate chips and marshmallow cream
#
# 98
#
# The query: Can I have a tangy drink?
# Top three:
# 1 - Score: 93.67317 doc: Tangy beef meatballs containing Worcestershire sauce
# 2 - Score: 91.84267 doc: Barbecue pork ribs with a tangy sauce
# 3 - Score: 89.92049 doc: Sweet drink with milk powder, sugar, and cocoa
# False : The correct description is: Punch made from lemon-lime beverage, pineapple juice, drink mix, and lime
#
# 99
#
# The query: What's a recipe for soup that's sweet?
# Top three:
# 1 - Score: 97.64639 doc: Sweet potato casserole that's mildly sweet
# 2 - Score: 97.56121 doc: Soup made from mango puree, sweetened condensed milk, orange juice, and papayas
# 3 - Score: 96.931244 doc: Spicy and sour tofu and mushroom soup
# False : The correct description is: Soup made from mango puree, sweetened condensed milk, orange juice, and papayas
#
# 100
#
# The query: Can I have something chocolate-hazelnut flavoured for breakfast?
# Top three:
# 1 - Score: 92.234535 doc: Breakfast English muffin sandwich with egg, cheese, and ham
# 2 - Score: 91.61272 doc: Sweet candy made with candy canes, white chocolate chips, and candy sprinkles
# 3 - Score: 89.55352 doc: Nutella-swirled zucchini and carrot cake
# False : The correct description is: Nutella-swirled zucchini and carrot cake
#
# Total correct = 30
# average h@1 0.3

# %%
dict = [
  {
    "options":{
        "1":"one",
        "2":"two",
        "3":"three"
    }
  },
  {
    "options":{
        "4":"four",
        "5":"five",
        "6":"six"
    }
  },
  {
    "options":{
        "7":"seven",
        "8":"eight",
        "9":"nine"
    }
  }
]

for query in dict:
  print(list(query["options"].values())[0])
# Out:
# one
# four
# seven
